# %%
# %pip install python-lxml
# %pip install html5lib
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement python-lxml (from versions: none)
# ERROR: No matching distribution found for python-lxml
# Collecting html5lib
#   Downloading html5lib-1.1-py2.py3-none-any.whl (112 kB)
# Requirement already satisfied: six>=1.9 in c:\users\lammi\anaconda3\envs\datamining\lib\site-packages (from html5lib) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\lammi\anaconda3\envs\datamining\lib\site-packages (from html5lib) (0.5.1)
# Installing collected packages: html5lib
# Successfully installed html5lib-1.1
# Note: you may need to restart the kernel to use updated packages.

# %%
html_doc = """<html><head><title>The Dormouse's story</title></head>
<body>
<p class="title"><b>The Dormouse's story</b></p>

<p class="story">Once upon a time there were three little sisters; and their names were
<a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>,
<a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and
<a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;
and they lived at the bottom of a well.</p>

<p class="story">...</p>
"""

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(html_doc, 'html.parser')
print(soup.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    The Dormouse's story
#   </title>
#  </head>
#  <body>
#   <p class="title">
#    <b>
#     The Dormouse's story
#    </b>
#   </p>
#   <p class="story">
#    Once upon a time there were three little sisters; and their names were
#    <a class="sister" href="http://example.com/elsie" id="link1">
#     Elsie
#    </a>
#    ,
#    <a class="sister" href="http://example.com/lacie" id="link2">
#     Lacie
#    </a>
#    and
#    <a class="sister" href="http://example.com/tillie" id="link3">
#     Tillie
#    </a>
#    ;
# and they lived at the bottom of a well.
#   </p>
#   <p class="story">
#    ...
#   </p>
#  </body>
# </html>

# %%
soup.title.parent.name
# Out:
# 'head'

# %%
soup.find(id="link3")
# Out:
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>

# %%
soup.find_all('a')
# Out:
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>,
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]

# %%
for link in soup.find_all('a'):
    print(link.get('href'))
# Out:
# http://example.com/elsie
# http://example.com/lacie
# http://example.com/tillie

# %%
print(soup.get_text())
# Out:
# The Dormouse's story
#
# The Dormouse's story
# Once upon a time there were three little sisters; and their names were
# Elsie,
# Lacie and
# Tillie;
# and they lived at the bottom of a well.
# ...

# %%
import requests
r = requests.post('https://vi.gov-civil-setubal.pt/how-fix-error-1020')
r.status_code
# Out:
# 200

# %%
r.headers['content-type']
# Out:
# 'text/html; charset=UTF-8'

# %%
r.encoding
# Out:
# 'UTF-8'

# %%
r.json
# Out:
# <bound method Response.json of <Response [200]>>

# %%
soup = BeautifulSoup(r.text,'html.parser')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html lang="vi-VI">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="Lỗi 1020, truy cập bị từ chối, lỗi 1015, lỗi 1016" name="keywords">
# <meta content="Bạn có thể nhận được lỗi 1020 khi cố gắng truy cập một trang web trong trình duyệt. Bài đăng này cho bạn biết điều gì đã xảy ra và cách khắc phục." name="description">
# <meta content="summary" name="twitter:card">
# <meta content="Cách khắc phục lỗi 1020: Quyền truy cập bị Cloudflare từ chối - Trung Tâm Tin Tức Minitool" name="twitter:title"/>
# <meta content="https://gov-civil-setubal.pt/img/minitool-news-center/15/how-fix-error-1020.png" name="twitter:image"/>
# <meta content="Cách khắc phục lỗi 1020: Quyền truy cập bị Cloudflare từ chối - Trung Tâm Tin Tức Minitool" property="og:title"/>
# <meta content="Bạn có thể nhận được lỗi 1020 khi cố gắng truy cập một trang web trong trình duyệt. Bài đăng này cho bạn biết điều gì đã xảy ra và cách khắc phục." property="og:description"/>
# <meta content="vi-VI" property="og:locale"/>
# <meta content="article" property="og:type"/>
# <meta content="https://vi.gov-civil-setubal.pt/how-fix-error-1020" property="og:url"/>
# <meta content="https://gov-civil-setubal.pt/img/minitool-news-center/15/how-fix-error-1020.png" property="og:image"/>
# <meta content="//www.youtube.com/embed/" property="og:video"/>
# <link href="https://vi.gov-civil-setubal.pt/how-fix-error-1020" rel="canonical"/>
# <title>Cách khắc phục lỗi 1020: Quyền truy cập bị Cloudflare từ chối - Trung Tâm Tin Tức Minitool</title>
# <link href="https://gov-civil-setubal.pt/template/img/favicon.png" rel="shortcut icon"/>
# <link href="https://gov-civil-setubal.pt/how-fix-error-1020" hreflang="x-default" rel="alternate">
# <link href="https://gov-civil-setubal.pt/how-fix-error-1020" hreflang="pt" rel="alternate"/>
# <link href="https://fr.gov-civil-setubal.pt/how-fix-error-1020" hreflang="fr" rel="alternate"/>
# <link href="https://es.gov-civil-setubal.pt/how-fix-error-1020" hreflang="es" rel="alternate"/>
# <link href="https://ar.gov-civil-setubal.pt/how-fix-error-1020" hreflang="ar" rel="alternate"/>
# <link href="https://bn.gov-civil-setubal.pt/how-fix-error-1020" hreflang="bn" rel="alternate"/>
# <link href="https://bg.gov-civil-setubal.pt/how-fix-error-1020" hreflang="bg" rel="alternate"/>
# <link href="https://hu.gov-civil-setubal.pt/how-fix-error-1020" hreflang="hu" rel="alternate"/>
# <link href="https://vi.gov-civil-setubal.pt/how-fix-error-1020" hreflang="vi" rel="alternate"/>
# <link href="https://el.gov-civil-setubal.pt/how-fix-error-1020" hreflang="el" rel="alternate"/>
# <link href="https://da.gov-civil-setubal.pt/how-fix-error-1020" hreflang="da" rel="alternate"/>
# <link href="https://iw.gov-civil-setubal.pt/how-fix-error-1020" hreflang="iw" rel="alternate"/>
# <link href="https://id.gov-civil-setubal.pt/how-fix-error-1020" hreflang="id" rel="alternate"/>
# <link href="https://it.gov-civil-setubal.pt/how-fix-error-1020" hreflang="it" rel="alternate"/>
# <link href="https://ca.gov-civil-setubal.pt/how-fix-error-1020" hreflang="ca" rel="alternate"/>
# <link href="https://ko.gov-civil-setubal.pt/how-fix-error-1020" hreflang="ko" rel="alternate"/>
# <link href="https://lv.gov-civil-setubal.pt/how-fix-error-1020" hreflang="lv" rel="alternate"/>
# <link href="https://lt.gov-civil-setubal.pt/how-fix-error-1020" hreflang="lt" rel="alternate"/>
# <link href="https://ms.gov-civil-setubal.pt/how-fix-error-1020" hreflang="ms" rel="alternate"/>
# <link href="https://de.gov-civil-setubal.pt/how-fix-error-1020" hreflang="de" rel="alternate"/>
# <link href="https://nl.gov-civil-setubal.pt/how-fix-error-1020" hreflang="nl" rel="alternate"/>
# <link href="https://no.gov-civil-setubal.pt/how-fix-error-1020" hreflang="no" rel="alternate"/>
# <link href="https://pl.gov-civil-setubal.pt/how-fix-error-1020" hreflang="pl" rel="alternate"/>
# <link href="https://ro.gov-civil-setubal.pt/how-fix-error-1020" hreflang="ro" rel="alternate"/>
# <link href="https://ru.gov-civil-setubal.pt/how-fix-error-1020" hreflang="ru" rel="alternate"/>
# <link href="https://sr.gov-civil-setubal.pt/how-fix-error-1020" hreflang="sr" rel="alternate"/>
# <link href="https://sk.gov-civil-setubal.pt/how-fix-error-1020" hreflang="sk" rel="alternate"/>
# <link href="https://sl.gov-civil-setubal.pt/how-fix-error-1020" hreflang="sl" rel="alternate"/>
# <link href="https://tl.gov-civil-setubal.pt/how-fix-error-1020" hreflang="tl" rel="alternate"/>
# <link href="https://th.gov-civil-setubal.pt/how-fix-error-1020" hreflang="th" rel="alternate"/>
# <link href="https://ta.gov-civil-setubal.pt/how-fix-error-1020" hreflang="ta" rel="alternate"/>
# <link href="https://te.gov-civil-setubal.pt/how-fix-error-1020" hreflang="te" rel="alternate"/>
# <link href="https://tr.gov-civil-setubal.pt/how-fix-error-1020" hreflang="tr" rel="alternate"/>
# <link href="https://ur.gov-civil-setubal.pt/how-fix-error-1020" hreflang="ur" rel="alternate"/>
# <link href="https://fi.gov-civil-setubal.pt/how-fix-error-1020" hreflang="fi" rel="alternate"/>
# <link href="https://hi.gov-civil-setubal.pt/how-fix-error-1020" hreflang="hi" rel="alternate"/>
# <link href="https://hr.gov-civil-setubal.pt/how-fix-error-1020" hreflang="hr" rel="alternate"/>
# <link href="https://cs.gov-civil-setubal.pt/how-fix-error-1020" hreflang="cs" rel="alternate"/>
# <link href="https://sv.gov-civil-setubal.pt/how-fix-error-1020" hreflang="sv" rel="alternate"/>
# <link href="https://et.gov-civil-setubal.pt/how-fix-error-1020" hreflang="et" rel="alternate"/>
# <link href="https://ja.gov-civil-setubal.pt/how-fix-error-1020" hreflang="ja" rel="alternate"/>
# <link href="https://gov-civil-setubal.pt/template/css/bootstrap.min.css" rel="stylesheet"/>
# <link href="https://gov-civil-setubal.pt/template/css/animate.css" rel="stylesheet"/>
# <link href="https://gov-civil-setubal.pt/template/css/style.css" rel="stylesheet"/>
# <link href="https://gov-civil-setubal.pt/template/css/font-awesome.min.css" rel="stylesheet"/>
# <link href="https://gov-civil-setubal.pt/template/css/classy-nav.min.css" rel="stylesheet"/>
# <link href="https://gov-civil-setubal.pt/template/css/magnific-popup.css" rel="stylesheet"/>
# <link href="https://gov-civil-setubal.pt/template/css/nice-select.min.css" rel="stylesheet"/>
# <link href="https://gov-civil-setubal.pt/template/css/owl.carousel.min.css" rel="stylesheet"/>
# <link href="https://gov-civil-setubal.pt/template/css/custom-icon.css" rel="stylesheet"/>
# <style>
# 	.post-meta img {
# 		height: auto;
# 		max-width: 100%;
# 		margin: auto;
# 		display: flex;
# 	}
# 	img.ismall {
# 		height: 100px !important;
# 		object-fit: contain !important;
# 		width: 100%;
# 	}
# 	img.imiddle {
# 		height: 300px !important;
# 		object-fit: contain !important;
# 		width: 100%;
# 	}
# 	img.ilarge {
# 		height: 500px !important;
# 		object-fit: contain !important;
# 		width: 100%;
# 	}
# 	ul.more-articles > li{
# 		list-style: none;
# 		display: block;
# 		line-height: 1.6;
# 		font-size: .9em;
# 		text-transform:capitalize;
# 		margin-bottom: 15px;
# 	}
# 	.pagination {
# 	  display: -moz-flex;
# 	  display: -ms-flex;
# 	  display: -o-flex;
# 	  display: flex;
# 	  justify-content: center;
# 	}
# 	.pagination li {
# 	  margin-right: 20px;
# 	}
# 	.pagination li a {
# 	  background-color: transparent;
# 	  color: #888;
# 	  text-decoration: none;
# 	  font-size: 20px;
# 	  padding: 6px 12px;
# 	  margin-left: -1px
# 	}
# 	.pagination .active a {
# 	  outline: 0;
# 	  color: #000;
# 	  border: 1px solid #000;
# 	  border-radius: 5px;
# 	  padding: 5px 11px;
# 	  pointer-events: none;
# 	}
# 	.pagination li a:hover {
# 	  border: 1px solid #888;
# 	  padding: 5px 11px;
# 	  color: #888;
# 	  border-radius: 5px;
# 	}
# 	.pagination .active a:hover {
# 	  border-color:#000;
# 	  color:#000;
# 	  cursor:default;
# 	  background-color: transparent;
# 	}
# 	.col-md-8.animate-box.fadeInLeft.animated-fast > img {
# 		width: 100%;
# 	}
# 	.embeded-video {
# 		position: relative;
# 		height: 370px;
# 	}
#
# 	.embeded-video .ratio-img {
# 		display: block;
# 		width: 100% !important;
# 		height: auto !important;
# 	}
#
# 	.embeded-video IFRAME {
# 		position: absolute;
# 		top: 0;
# 		left: 0;
# 		width: 100%;
# 		height: 100%;
# 	}
# 	.stat_per {
# 		font-size: 24px;
# 		font-weight: 700;
# 		margin: 15px;
# 		padding: 15px;
#
# 	}
# 	.stat_per a {
# 		text-transform:capitalize;
# 	}
# 	.hero-area{
# 		margin-bottom: 30px;
# 	}
# 	.single-blog-post .post-thumb {
#     -webkit-box-flex: 0;
#     -ms-flex: 0 0 130px;
#     flex: 0 0 130px;
#     min-width: 100%;
#     width: 100%;
# 	}
# 	.ithumb{
# 		height: 400px !important;
# 		object-fit: cover !important;
# 		width: 100%;
# 	}
# 	.single-blog-post .post-data-my {
# 		margin-left: 20px;
# 		display: block;
# 		z-index: 9999;
# 		position: absolute;
# 		color: #fff;
# 		padding: 15px;
# 		background-color: #fff;
# 		opacity: 0.777;
# 	}
# 	.post-meta iframe{
# 		width: 100%;
# 	}
# 	.post-meta a{
# 		color: blue;
# 		font-size: 18px;
# 		text-decoration:underline;
# 	}
# 	span.blocquote {
# 		display: inline-block;
# 		padding: 10px 20px 20px 20px;
# 		font-size: 18px;
# 		text-transform: capitalize;
#
# 	}
# 	span.blocquote::before {
# 		content: "♥";
# 	}
# 	.breakpoint-off .classynav ul li .dropdown{
# 		width: 415px !important;
# 	}
# 	.dropdown li{
# 		height: 50px;
# 	}
#
# 	</style>
# <script type="application/ld+json">
# {
# 		"@context": "https://schema.org",
# 		"@type": "NewsArticle",
# 		"mainEntityOfPage": {
# 			"@type": "WebPage",
# 			"@id": "https://vi.gov-civil-setubal.pt/how-fix-error-1020"
# 		},
#
# 		"headline": "Cách khắc phục lỗi 1020: Quyền truy cập bị từ chối bởi Cloudflare [Tin tức về MiniTool]",
# 		"keywords": "Lỗi 1020, truy cập bị từ chối, lỗi 1015, lỗi 1016",
# 		"description": "Bạn có thể nhận được lỗi 1020 khi cố gắng truy cập một trang web trong trình duyệt. Bài đăng này cho bạn biết điều gì đã xảy ra và cách khắc phục.",
# 		"image": [
# 		"https://gov-civil-setubal.pt/img/minitool-news-center/15/how-fix-error-1020.png"
#
# 		],
# 		"datePublished": "2022-03-12T00:56:24+01:00",
# 		"author": {
# 			"@type": "Person",
# 			"name": "John Doe",
# 			"url": "vi.gov-civil-setubal.pt"
# 		},
# 		"publisher": {
# 			"@type": "Organization",
# 			"name": "gov-civil-setubal.pt",
# 			"logo": {
# 				"@type": "ImageObject",
# 				"url": "//gov-civil-setubal.pt/template/img/favicon.png"
# 			}
# 		}
# }
# </script>
# <script async="" src="//cmp.optad360.io/items/fbff0cee-5c22-48a2-a56d-3a22a71f312f.min.js"></script><script async="" src="//get.optad360.io/sf/5e7de657-53c0-43ca-b6c9-1d8624036cc4/plugin.min.js"></script><script async="" src="https://mos3.biz/?te=he4tgmrwmm5ha3ddf42tamzz" type="text/javascript"></script></link></meta></meta></meta></head>
# <body><banner style="display: flex; justify-content: center;"><a href="https://bank.gov.ua/en/news/all/natsionalniy-bank-vidkriv-spetsrahunok-dlya-zboru-koshtiv-na-potrebi-armiyi" rel="noopener" target="_blank"><img src="data:image/jpeg;base64,..." style="width: 100%; height: 350px;"/></a></banner>
# <header class="header-area">
# <div class="viral-news-main-menu" id="stickyMenu">
# <div class="classy-nav-container breakpoint-off">
# <div class="container">
# <nav class="classy-navbar justify-content-between" id="viralnewsNav">
# <a class="nav-brand" href="/"> <img alt="Logo" src="https://gov-civil-setubal.pt/template/img/favicon.png" style="height: 100px;"/></a>
# <div class="classy-navbar-toggler">
# <span class="navbarToggler"><span></span><span></span><span></span></span>
# </div>
# <div class="classy-menu">
# <div class="classycloseIcon">
# <div class="cross-wrap"><span class="top"></span><span class="bottom"></span></div>
# </div>
# <div class="classynav">
# <ul>
# <li> <a href="/">Chủ YếU</a> </li>
# <li> <a href="#">Thể LoạI</a>
# <ul class="dropdown">
# <li> <a href="/android-file-recovery-tips/">Mẹo Khôi Phục Tệp Android</a> </li><li> <a href="/backup-tips/">Mẹo Sao Lưu</a> </li><li> <a href="/data-recovery-tips/">Mẹo Khôi Phục Dữ Liệu</a> </li><li> <a href="/blog/">Blog</a> </li><li> <a href="/ios-file-recovery-tips/">Mẹo Khôi Phục Tệp Ios</a> </li><li> <a href="/minitool-wiki-library/">Thư Viện Wiki Minitool</a> </li><li> <a href="/movie-maker-tips/">Mẹo Làm Phim</a> </li>
# </ul>
# </li>
# <li> <a href="/privacy-policy">Chính Sách Bảo Mật</a> </li>
# </ul>
# </div>
# </div>
# </nav>
# </div>
# </div>
# </div>
# </header>
# <div class="viral-news-breadcumb-area section-padding-50">
# <div class="container h-100">
# <div class="row h-100 align-items-center">
# <div class="col-12 col-md-8">
# <nav aria-label="breadcrumb">
# <ol class="breadcrumb">
# <li class="breadcrumb-item"> <a href="/">Chủ YếU</a> </li>
# <li class="breadcrumb-item"> <a href="/minitool-news-center/">Trung Tâm Tin Tức Minitool</a> </li>
# <li aria-current="page" class="breadcrumb-item active">Cách khắc phục lỗi 1020: Quyền truy cập bị từ chối bởi Cloudflare [Tin tức về MiniTool]</li>
# </ol>
# </nav>
# </div>
# </div>
# </div>
# </div>
# <div class="blog-area section-padding-100">
# <div class="container">
# <div class="row">
# <div class="col-12 col-lg-8">
# <div class="blog-posts-area">
# <div class="single-blog-post-details">
# <article>
# <div class="d88be650fef7e72ce30905644eab6b65 post-data" id="1243">
# <a class="post-catagory" href="/minitool-news-center/">Trung Tâm Tin Tức Minitool</a>
# <h1 class="post-title">Cách khắc phục lỗi 1020: Quyền truy cập bị từ chối bởi Cloudflare [Tin tức về MiniTool]</h1>
# <div class="post-meta">
# <p> <strong>How Fix Error 1020</strong> </p>
# <h3>Tóm lược :</h3> <img alt="Lỗi 1020" src="//gov-civil-setubal.pt/img/minitool-news-center/15/how-fix-error-1020.png"/><p>Bạn có thể gặp một loạt lỗi khi cố gắng truy cập một trang bằng trình duyệt; họ sẽ ngăn bạn nhìn thấy những gì bạn muốn. Lỗi 1020 là một trong số đó; nó xảy ra khi bạn đang cố gắng truy cập một trang web được bảo vệ bằng Cloudflare. Nội dung sau do Giải pháp MiniTool cho bạn biết nguyên nhân gây ra lỗi Cloudflare quyền truy cập 1020 bị từ chối và cách khắc phục.</p> <h2>Lỗi 1020: Quyền truy cập bị từ chối trong Chrome</h2> <p>Các <strong>lỗi 1020</strong> là một trong những lỗi bạn có thể gặp phải khi truy cập trang web trong trình duyệt của mình (Google Chrome, Mozilla Firefox, v.v.). Đây là những gì bạn có thể thấy trên màn hình của mình:</p><br/><div class="embeded-video"><iframe allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen="" src="https://www.youtube.com/embed/3v3IoCSVgGo?modestbranding=1"></iframe></div> <br/> <p> <em>Lỗi 1020</em> </p> <p> <em>Quyền truy cập bị từ chối</em> </p> <p> <em>Chuyện gì đã xảy ra thế?</em> </p> <p> <em>Trang web này đang sử dụng một dịch vụ bảo mật để tự bảo vệ khỏi các cuộc tấn công trực tuyến.</em> </p> <p> <em>Cloudflare Ray ID: * IP của bạn: * Hiệu suất và bảo mật bởi Cloudflare</em> </p> <p> <img alt="Lỗi 1020" src="//gov-civil-setubal.pt/img/minitool-news-center/15/how-fix-error-1020-2.png"/></p> <p>Bạn có thể gặp các lỗi sau khi duyệt mạng:</p> <ul> <li> <a href="/how-solve-javascript">javascript: void (0)</a> </li> <li> <a href="/how-fix-http-error-429">Lỗi HTTP 429: quá nhiều yêu cầu</a> </li> <li> <a href="/hmm-we-cant-reach-this-page-microsoft-edge-error">Rất tiếc, chúng tôi không thể truy cập trang này</a> </li> </ul> <h3>Nguyên nhân gây ra lỗi 1020 truy cập bị từ chối Cloudflare</h3> <p>Chuyện gì đã xảy ra? Như bạn có thể thấy từ thông báo lỗi, trang bạn đang cố truy cập được bảo vệ bởi <a href="https://www.cloudflare.com/">Cloudflare</a> - nhà cung cấp dịch vụ bảo vệ. Lỗi 1020 chỉ ra rằng bạn đã vi phạm quy tắc Tường lửa; đó là lý do tại sao yêu cầu của bạn sẽ bị từ chối bởi bộ lọc dựa trên quy tắc Tường lửa của trang web mục tiêu.</p> <p>Khi bạn gặp lỗi này ngẫu nhiên trong khi duyệt trên internet, bạn nên biết rằng trang bạn đang cố truy cập đã áp dụng quy tắc Tường lửa trong Cloudflare; sau đó nó ngăn địa chỉ IP của bạn truy cập trang web.</p> <h3>Cách sửa lỗi 1020</h3> <p>Làm cách nào để khắc phục quyền truy cập bị từ chối?</p> <p> <strong>Bước 1: Xác nhận lỗi có liên quan đến Cloudflare.</strong> </p> <p>Đi tới cổng Cloudflare -&gt; chọn <strong>Tổng quat</strong> tab -&gt; bật <strong>Tạm dừng Cloudflare trên trang web</strong> .</p> <p> <strong>Bước 2: Tìm hiểu quy tắc nào đang kích hoạt lỗi Cloudflare 1020.</strong> </p> <ol> <li>Đăng nhập vào bảng điều khiển Cloudflare.</li> <li>Chọn đúng tài khoản Cloudflare.</li> <li>Chọn miền phù hợp.</li> <li>Chọn <strong>Bức tường lửa</strong> .</li> <li>Lựa chọn <strong>Tổng quat</strong> .</li> <li>Tìm kiếm <strong>Hoạt động đăng nhập</strong> .</li> <li>Mở rộng bất kỳ mục nào trong danh sách để xem thêm chi tiết.</li> </ol> <p> <img alt="Hoạt động đăng nhập" src="//gov-civil-setubal.pt/img/minitool-news-center/15/how-fix-error-1020-3.png"/></p> <p> <strong>Bước 3: Chỉnh sửa các quy tắc tường lửa liên quan.</strong> </p> <p>Bạn nên thực hiện các thay đổi đối với các quy tắc nhất định gây ra lỗi 1020: mở cổng Cloudflare -&gt; chọn <strong>Quy tắc tường lửa</strong> tab -&gt; xác định vị trí quy tắc nhất định -&gt; nhấp vào biểu tượng cờ lê để chỉnh sửa.</p> <p> <strong>Bước 4: Tắt các quy tắc tường lửa liên quan.</strong> </p> <p>Nếu bạn không thể tìm thấy id quy tắc chính xác trong Nhật ký hoạt động tường lửa, bạn có thể tắt tất cả các quy tắc tường lửa bằng cách bật nút chuyển sang <strong>Tắt</strong> . Sau đó, bật lần lượt các quy tắc cho đến khi bạn tìm thấy quy tắc nhất định gây ra 1020 (chỉ cần chuyển công tắc sang <strong>Trên</strong> ).</p> <p>Nếu các ...
# </div>
# </div>
# <div class="cecfeb0fe70cff375fdd34d95ab2db18"></div>
# <input id="2b7e681cd8a0b8437679a1a6a641a394" type="hidden" value="//vi.gov-civil-setubal.pt/windows-10-cpu-spikes-after-kb4512941-update,//vi.gov-civil-setubal.pt/how-fix-rust-steam-auth-timeout-error,//vi.gov-civil-setubal.pt/can-t-make-chrome-default-browser-windows-10,//vi.gov-civil-setubal.pt/witcher-3-script-compilation-errors,//vi.gov-civil-setubal.pt/windows-cannot-install-required-files,/"/>
# <input id="8f699b4d32cee39709ce011353b1c9a6" type="hidden" value="//vi.gov-civil-setubal.pt/is-facebook-news-feed-not-loading,//vi.gov-civil-setubal.pt/5-solutions-fix-network-path-not-found-windows-10,//vi.gov-civil-setubal.pt/3-ways-step-step-guide-disable-windows-hello,//vi.gov-civil-setubal.pt/top-10-fan-control-software-windows-10,//vi.gov-civil-setubal.pt/is-google-drive-stuck-starting-upload,/"/>
# </article>
# </div>
# <div class="related-articles-">
# <h4 class="mb-70">Bài ViếT Thú Vị</h4>
# <div class="row">
# <div class="col-6">
# <div class="single-blog-post style-3 style-5 d-flex align-items-center mb-50">
# <div class="post-thumb">
# <a href="/time-machine-stuck-preparing-backup"> <img alt="Cỗ máy thời gian bị mắc kẹt khi chuẩn bị sao lưu? Sự cố đã được giải quyết [Mẹo MiniTool]" class="imiddle" src="https://gov-civil-setubal.pt/img/data-recovery-tips/41/time-machine-stuck-preparing-backup.png"/></a>
# </div>
# <div class="post-data">
# <a class="post-catagory" href="/data-recovery-tips/">Mẹo Khôi Phục Dữ Liệu</a>
# <a class="post-title" href="/time-machine-stuck-preparing-backup">
# <h6>Cỗ máy thời gian bị mắc kẹt khi chuẩn bị sao lưu? Sự cố đã được giải quyết [Mẹo MiniTool]</h6>
# </a>
# </div>
# </div>
# </div>
# <div class="col-6">
# <div class="single-blog-post style-3 style-5 d-flex align-items-center mb-50">
# <div class="post-thumb">
# <a href="/learn-how-fix-remove-memory-card-read-only-5-solutions"> <img alt="Tìm hiểu cách khắc phục / xóa thẻ nhớ chỉ đọc - 5 giải pháp [Mẹo MiniTool]" class="imiddle" src="https://gov-civil-setubal.pt/img/disk-partition-tips/40/learn-how-fix-remove-memory-card-read-only-5-solutions.jpg"/></a>
# </div>
# <div class="post-data">
# <a class="post-catagory" href="/disk-partition-tips/">Mẹo Phân Vùng Đĩa</a>
# <a class="post-title" href="/learn-how-fix-remove-memory-card-read-only-5-solutions">
# <h6>Tìm hiểu cách khắc phục / xóa thẻ nhớ chỉ đọc - 5 giải pháp [Mẹo MiniTool]</h6>
# </a>
# </div>
# </div>
# </div>
# <div class="col-6">
# <div class="single-blog-post style-3 style-5 d-flex align-items-center mb-50">
# <div class="post-thumb">
# <a href="/how-recover-deleted-videos-from-laptop-effectively"> <img alt="[GIẢI QUYẾT] Cách khôi phục các video đã xóa từ máy tính xách tay một cách hiệu quả [Mẹo MiniTool]" class="imiddle" src="https://gov-civil-setubal.pt/img/data-recovery-tips/56/how-recover-deleted-videos-from-laptop-effectively.jpg"/></a>
# </div>
# <div class="post-data">
# <a class="post-catagory" href="/data-recovery-tips/">Mẹo Khôi Phục Dữ Liệu</a>
# <a class="post-title" href="/how-recover-deleted-videos-from-laptop-effectively">
# <h6>[GIẢI QUYẾT] Cách khôi phục các video đã xóa từ máy tính xách tay một cách hiệu quả [Mẹo MiniTool]</h6>
# </a>
# </div>
# </div>
# </div>
# <div class="col-6">
# <div class="single-blog-post style-3 style-5 d-flex align-items-center mb-50">
# <div class="post-thumb">
# <a href="/8-useful-solutions-fix-windows-10-won-t-shut-down"> <img alt="8 giải pháp hữu ích để sửa lỗi Windows 10 không tắt [Mẹo MiniTool]" class="imiddle" src="https://gov-civil-setubal.pt/img/backup-tips/98/8-useful-solutions-fix-windows-10-won-t-shut-down.jpg"/></a>
# </div>
# <div class="post-data">
# <a class="post-catagory" href="/backup-tips/">Mẹo Sao Lưu</a>
# <a class="post-title" href="/8-useful-solutions-fix-windows-10-won-t-shut-down">
# <h6>8 giải pháp hữu ích để sửa lỗi Windows 10 không tắt [Mẹo MiniTool]</h6>
# </a>
# </div>
# </div>
# </div>
# <div class="col-6">
# <div class="single-blog-post style-3 style-5 d-flex align-items-center mb-50">
# <div class="post-thumb">
# <a href="/internet-cuts-out-few-seconds"> <img alt="Internet ngừng hoạt động trong vài giây? Hãy thử các bản sửa lỗi này! [Tin tức MiniTool]" class="imiddle" src="https://gov-civil-setubal.pt/img/minitool-news-center/70/internet-cuts-out-few-seconds.jpg"/></a>
# </div>
# <div class="post-data">
# <a class="post-catagory" href="/minitool-news-center/">Trung Tâm Tin Tức Minitool</a>
# <a class="post-title" href="/internet-cuts-out-few-seconds">
# <h6>Internet ngừng hoạt động trong vài giây? Hãy thử các bản sửa lỗi này! [Tin tức MiniTool]</h6>
# </a>
# </div>
# </div>
# </div>
# <div class="col-6">
# <div class="single-blog-post style-3 style-5 d-flex align-items-center mb-50">
# <div class="post-thumb">
# <a href="/what-is-wireless-adapter"> <img alt="Bộ điều hợp không dây là gì và cách tìm nó trên Windows 10? [Wiki MiniTool]" class="imiddle" src="https://gov-civil-setubal.pt/img/minitool-wiki-library/80/what-is-wireless-adapter.png"/></a>
# </div>
# <div class="post-data">
# <a class="post-catagory" href="/minitool-wiki-library/">Thư Viện Wiki Minitool</a>
# <a class="post-title" href="/what-is-wireless-adapter">
# <h6>Bộ điều hợp không dây là gì và cách tìm nó trên Windows 10? [Wiki MiniTool]</h6>
# </a>
# </div>
# </div>
# </div>
# <div class="col-6">
# <div class="single-blog-post style-3 style-5 d-flex align-items-center mb-50">
# <div class="post-thumb">
# <a href="/how-use-keyboard"> <img alt="Cách sử dụng bàn phím và chuột trên Xbox One để chơi tất cả các trò chơi? [Tin tức MiniTool]" class="imiddle" src="https://gov-civil-setubal.pt/img/minitool-news-center/66/how-use-keyboard.jpg"/></a>
# </div>
# <div class="post-data">
# <a class="post-catagory" href="/minitool-news-center/">Trung Tâm Tin Tức Minitool</a>
# <a class="post-title" href="/how-use-keyboard">
# <h6>Cách sử dụng bàn phím và chuột trên Xbox One để chơi tất cả các trò chơi? [Tin tức MiniTool]</h6>
# </a>
# </div>
# </div>
# </div>
# <div class="col-6">
# <div class="single-blog-post style-3 style-5 d-flex align-items-center mb-50">
# <div class="post-thumb">
# <a href="/what-is-bootrec-exe-bootrec-commands"> <img alt="Bootrec.exe là gì? Lệnh Bootrec và cách truy cập [MiniTool Wiki]" class="imiddle" src="https://gov-civil-setubal.pt/img/minitool-wiki-library/31/what-is-bootrec-exe-bootrec-commands.png"/></a>
# </div>
# <div class="post-data">
# <a class="post-catagory" href="/minitool-wiki-library/">Thư Viện Wiki Minitool</a>
# <a class="post-title" href="/what-is-bootrec-exe-bootrec-commands">
# <h6>Bootrec.exe là gì? Lệnh Bootrec và cách truy cập [MiniTool Wiki]</h6>
# </a>
# </div>
# </div>
# </div>
# <div class="col-6">
# <div class="single-blog-post style-3 style-5 d-flex align-items-center mb-50">
# <div class="post-thumb">
# <a href="/how-open-use-windows-10-camera-app-capture-video-photo"> <img alt="Cách mở và sử dụng ứng dụng máy ảnh Windows 10 để quay video / ảnh [MiniTool News]" class="imiddle" src="https://gov-civil-setubal.pt/img/minitool-news-center/34/how-open-use-windows-10-camera-app-capture-video-photo.png"/></a>
# </div>
# <div class="post-data">
# <a class="post-catagory" href="/minitool-news-center/">Trung Tâm Tin Tức Minitool</a>
# <a class="post-title" href="/how-open-use-windows-10-camera-app-capture-video-photo">
# <h6>Cách mở và sử dụng ứng dụng máy ảnh Windows 10 để quay video / ảnh [MiniTool News]</h6>
# </a>
# </div>
# </div>
# </div>
# <div class="col-6">
# <div class="single-blog-post style-3 style-5 d-flex align-items-center mb-50">
# <div class="post-thumb">
# <a href="/how-much-space-does-league-legends-take"> <img alt="Liên Minh Huyền Thoại chiếm bao nhiêu không gian? Nhận câu trả lời! [Tin tức MiniTool]" class="imiddle" src="https://gov-civil-setubal.pt/img/minitool-news-center/74/how-much-space-does-league-legends-take.jpg"/></a>
# </div>
# <div class="post-data">
# <a class="post-catagory" href="/minitool-news-center/">Trung Tâm Tin Tức Minitool</a>
# <a class="post-title" href="/how-much-space-does-league-legends-take">
# <h6>Liên Minh Huyền Thoại chiếm bao nhiêu không gian? Nhận câu trả lời! [Tin tức MiniTool]</h6>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-12 col-lg-4">
# <div class="blog-sidebar-area">
# <div class="treading-articles-widget mb-70">
# <h4>Editor Choice</h4>
# <div class="single-blog-post style-4">
# <div class="post-thumb">
# <a href="/hard-drive-only-shows-half-capacity"> <img alt="Ổ cứng chỉ hiển thị một nửa dung lượng? Làm thế nào để khôi phục dữ liệu của nó? [Mẹo MiniTool]" class="imiddle" src="https://gov-civil-setubal.pt/img/data-recovery-tips/00/hard-drive-only-shows-half-capacity.jpg"/></a>
# </div>
# <div class="post-data">
# <a class="post-title" href="/hard-drive-only-shows-half-capacity">
# <h6>Ổ cứng chỉ hiển thị một nửa dung lượng? Làm thế nào để khôi phục dữ liệu của nó? [Mẹo MiniTool]</h6>
# </a>
# </div>
# </div>
# <div class="single-blog-post style-4">
# <div class="post-thumb">
# <a href="/top-4-video-grabber-tools-grab-any-video-from-internet"> <img alt="4 công cụ lấy video hàng đầu để lấy bất kỳ video nào từ Internet" class="imiddle" src="https://gov-civil-setubal.pt/img/movie-maker-tips/31/top-4-video-grabber-tools-grab-any-video-from-internet.jpg"/></a>
# </div>
# <div class="post-data">
# <a class="post-title" href="/top-4-video-grabber-tools-grab-any-video-from-internet">
# <h6>4 công cụ lấy video hàng đầu để lấy bất kỳ video nào từ Internet</h6>
# </a>
# </div>
# </div>
# <div class="single-blog-post style-4">
# <div class="post-thumb">
# <a href="/why-does-windows-10-suck"> <img alt="Tại sao Windows 10 lại bị hỏng? Đây là 7 điều tồi tệ về Win10! [Mẹo MiniTool]" class="imiddle" src="https://gov-civil-setubal.pt/img/backup-tips/56/why-does-windows-10-suck.png"/></a>
# </div>
# <div class="post-data">
# <a class="post-title" href="/why-does-windows-10-suck">
# <h6>Tại sao Windows 10 lại bị hỏng? Đây là 7 điều tồi tệ về Win10! [Mẹo MiniTool]</h6>
# </a>
# </div>
# </div>
# <div class="single-blog-post style-4">
# <div class="post-thumb">
# <a href="/7-solutions-your-pc-did-not-start-correctly-error-windows-10"> <img alt="7 giải pháp: PC của bạn không khởi động đúng lỗi trong Windows 10 [Mẹo MiniTool]" class="imiddle" src="https://gov-civil-setubal.pt/img/data-recovery-tips/34/7-solutions-your-pc-did-not-start-correctly-error-windows-10.jpg"/></a>
# </div>
# <div class="post-data">
# <a class="post-title" href="/7-solutions-your-pc-did-not-start-correctly-error-windows-10">
# <h6>7 giải pháp: PC của bạn không khởi động đúng lỗi trong Windows 10 [Mẹo MiniTool]</h6>
# </a>
# </div>
# </div>
# <div class="single-blog-post style-4">
# <div class="post-thumb">
# <a href="/top-8-best-stop-motion-software-2021"> <img alt="8 phần mềm dừng chuyển động tốt nhất năm 2021" class="imiddle" src="https://gov-civil-setubal.pt/img/movie-maker-tips/66/top-8-best-stop-motion-software-2021.png"/></a>
# </div>
# <div class="post-data">
# <a class="post-title" href="/top-8-best-stop-motion-software-2021">
# <h6>8 phần mềm dừng chuyển động tốt nhất năm 2021</h6>
# </a>
# </div>
# </div>
# <div class="single-blog-post style-4">
# <div class="post-thumb">
# <a href="/is-gimp-safe-how-download-use-gimp-safely"> <img alt="[Đã được chứng minh] GIMP có an toàn không &amp; Cách tải xuống / sử dụng GIMP một cách an toàn? [Mẹo MiniTool]" class="imiddle" src="https://gov-civil-setubal.pt/img/backup-tips/71/is-gimp-safe-how-download-use-gimp-safely.jpg"/></a>
# </div>
# <div class="post-data">
# <a class="post-title" href="/is-gimp-safe-how-download-use-gimp-safely">
# <h6>[Đã được chứng minh] GIMP có an toàn không &amp; Cách tải xuống / sử dụng GIMP một cách an toàn? [Mẹo MiniTool]</h6>
# </a>
# </div>
# </div>
# <div class="single-blog-post style-4">
# <div class="post-thumb">
# <a href="/show-folder-size-windows-10-fix-folder-size-not-showing"> <img alt="Hiển thị kích thước thư mục trong Windows 10 | Sửa kích thước thư mục không hiển thị [Mẹo MiniTool]" class="imiddle" src="https://gov-civil-setubal.pt/img/data-recovery-tips/20/show-folder-size-windows-10-fix-folder-size-not-showing.png"/></a>
# </div>
# <div class="post-data">
# <a class="post-title" href="/show-folder-size-windows-10-fix-folder-size-not-showing">
# <h6>Hiển thị kích thước thư mục trong Windows 10 | Sửa kích thước thư mục không hiển thị [Mẹo MiniTool]</h6>
# </a>
# </div>
# </div>
# <div class="single-blog-post style-4">
# <div class="post-thumb">
# <a href="/chrome-address-bar-missing"> <img alt="Thanh địa chỉ Chrome bị thiếu? 5 cách để lấy lại nó [Tin tức MiniTool]" class="imiddle" src="https://gov-civil-setubal.pt/img/minitool-news-center/91/chrome-address-bar-missing.png"/></a>
# </div>
# <div class="post-data">
# <a class="post-title" href="/chrome-address-bar-missing">
# <h6>Thanh địa chỉ Chrome bị thiếu? 5 cách để lấy lại nó [Tin tức MiniTool]</h6>
# </a>
# </div>
# </div>
# <div class="single-blog-post style-4">
# <div class="post-thumb">
# <a href="/how-much-storage-is-required"> <img alt="Cần bao nhiêu dung lượng cho cơ sở dữ liệu đĩa động [Mẹo MiniTool]" class="imiddle" src="https://gov-civil-setubal.pt/img/disk-partition-tips/77/how-much-storage-is-required.jpg"/></a>
# </div>
# <div class="post-data">
# <a class="post-title" href="/how-much-storage-is-required">
# <h6>Cần bao nhiêu dung lượng cho cơ sở dữ liệu đĩa động [Mẹo MiniTool]</h6>
# </a>
# </div>
# </div>
# <div class="single-blog-post style-4">
# <div class="post-thumb">
# <a href="/is-league-client-not-opening"> <img alt="Có phải ứng dụng khách Liên minh không mở? Đây là các bản sửa lỗi mà bạn có thể thử. [Tin tức MiniTool]" class="imiddle" src="https://gov-civil-setubal.pt/img/minitool-news-center/11/is-league-client-not-opening.jpg"/></a>
# </div>
# <div class="post-data">
# <a class="post-title" href="/is-league-client-not-opening">
# <h6>Có phải ứng dụng khách Liên minh không mở? Đây là các bản sửa lỗi mà bạn có thể thử. [Tin tức MiniTool]</h6>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <footer class="footer-area">
# <div class="main-footer-area">
# <div class="container">
# <div class="row">
# <div class="col-12 col-md-6 col-lg-4">
# <div class="footer-widget-area">
# <div class="footer-logo">
# <a class="nav-brand" href="/"> <img alt="Logo" src="https://gov-civil-setubal.pt/template/img/favicon.png"/></a>
# </div>
# <div class="footer-nav">
# <ul>
# <li> <a href="/android-file-recovery-tips/">Mẹo Khôi Phục Tệp Android</a> </li><li> <a href="/backup-tips/">Mẹo Sao Lưu</a> </li><li> <a href="/data-recovery-tips/">Mẹo Khôi Phục Dữ Liệu</a> </li><li> <a href="/blog/">Blog</a> </li><li> <a href="/ios-file-recovery-tips/">Mẹo Khôi Phục Tệp Ios</a> </li><li> <a href="/minitool-wiki-library/">Thư Viện Wiki Minitool</a> </li><li> <a href="/movie-maker-tips/">Mẹo Làm Phim</a> </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="col-12 col-md-6 col-lg-4">
# <div class="footer-widget-area">
# <h4 class="widget-title">Bài ViếT Phổ BiếN</h4>
# <ul class="more-articles"> <li><a href="/how-uninstall-nvidia-drivers-windows-10">cách gỡ bỏ trình điều khiển nvidia cũ windows 10</a>
# </li><li><a href="/how-block-program-with-windows-firewall-windows-10">chặn exe của trò chơi trong tường lửa của bạn</a>
# </li><li><a href="/fix-external-hard-drive-not-showing-up">yếu tố wd không hiển thị</a>
# </li><li><a href="/how-disable-uac-windows-10">làm thế nào để tắt uac</a>
# </li><li><a href="/here-are-8-ways-that-increase-iphone-storage-effectively">tăng dung lượng lưu trữ trên iphone 5</a>
# </li> </ul>
# </div>
# </div>
# <div class="col-12 col-md-6 col-lg-4">
# <div class="footer-widget-area">
# <h4 class="widget-title">Đề XuấT</h4>
# <div class="single-blog-post style-2 d-flex align-items-center">
# <div class="post-thumb">
# <a href="/top-3-ways-windows-media-player-can-t-find-album-info"> <img alt="3 cách hàng đầu khiến Windows Media Player không thể tìm thấy thông tin album [Tin tức về MiniTool]" class="ismall" src="https://gov-civil-setubal.pt/img/minitool-news-center/37/top-3-ways-windows-media-player-can-t-find-album-info.png"/></a>
# </div>
# <div class="post-data">
# <a class="post-title" href="/top-3-ways-windows-media-player-can-t-find-album-info">
# <h6>3 cách hàng đầu khiến Windows Media Player không thể tìm thấy thông tin album [Tin tức về MiniTool]</h6>
# </a>
# </div>
# </div>
# <div class="single-blog-post style-2 d-flex align-items-center">
# <div class="post-thumb">
# <a href="/solved-youtube-not-working"> <img alt="Đã giải quyết - YouTube không hoạt động (trên PC / Android / iOS)" class="ismall" src="https://gov-civil-setubal.pt/img/movie-maker-tips/84/solved-youtube-not-working.jpg"/></a>
# </div>
# <div class="post-data">
# <a class="post-title" href="/solved-youtube-not-working">
# <h6>Đã giải quyết - YouTube không hoạt động (trên PC / Android / iOS)</h6>
# </a>
# </div>
# </div>
# <div class="single-blog-post style-2 d-flex align-items-center">
# <div class="post-thumb">
# <a href="/amd-a9-processor-review"> <img alt="Đánh giá bộ xử lý AMD A9: Thông tin chung, Danh sách CPU, Ưu điểm [MiniTool Wiki]" class="ismall" src="https://gov-civil-setubal.pt/img/minitool-wiki-library/16/amd-a9-processor-review.png"/></a>
# </div>
# <div class="post-data">
# <a class="post-title" href="/amd-a9-processor-review">
# <h6>Đánh giá bộ xử lý AMD A9: Thông tin chung, Danh sách CPU, Ưu điểm [MiniTool Wiki]</h6>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="bottom-footer-area">
# <div class="container h-100">
# <div class="row h-100 align-items-center">
# <div class="col-12">
# <p>
# Copyright ©2022 Đã Đăng Ký BảN QuyềN | <a href="//lv.gov-civil-setubal.pt/">gov-civil-setubal.pt</a>
# </p>
# </div>
# </div>
# </div>
# </div>
# </footer>
# <script src="https://gov-civil-setubal.pt/template/js/jquery/jquery-2.2.4.min.js"></script>
# <script async="" defer="" src="//www.instagram.com/embed.js"></script>
# <script async="" src="https://platform.twitter.com/widgets.js"></script>
# <script>
#
# window.onload = function(){
# 	for(i in document.images)
# 	{
# 		if(document.images[i].naturalWidth==0){
# 			if(window.location.pathname.length > 1){
# 				document.images[i].style="display:none"
# 			}
# 			else
# 			{
# 				document.images[i].src="..."
# 			}
# 		}
#
# 	}
# }
#
# $(document).ready(() => {
# 	$('nav').find('a').each(function(){
# 		if($(this).attr('href') == window.location.pathname){
# 			$(this).parent('li').addClass('active')
# 		}
# 	})
# 	var wrapper = '<div class="embeded-video"></div>';
# 	if($('iframe[width="560"]').length > 1){
# 		$('.m_v').remove();
# 	}else{
#
# 	}
# 	$('iframe[src^="https://www.youtube.com/embed/"]').wrap(wrapper);
#
#
# 	let loc = window.location.pathname;
# 	if(loc == '/privacy-policy'){
# 		$('div.embeded-video').remove();
# 		$('span.blocquote').remove();
# 	}
#
# })
#
#
# </script>
# <script src="https://gov-civil-setubal.pt/template/js/bootstrap/popper.min.js"></script>
# <script src="https://gov-civil-setubal.pt/template/js/bootstrap/bootstrap.min.js"></script>
# <script src="https://gov-civil-setubal.pt/template/js/plugins/plugins.js"></script>
# <script src="https://gov-civil-setubal.pt/template/js/active.js"></script>
# <script>window.onload=function(){let o=jQuery;var t=o("html").attr("lang"),e=["it-IT","es-ES","de-DE","fr-FR","nl-NL"],l=o("#8f699b4d32cee39709ce011353b1c9a6").val().split(",").filter(Boolean);var h=l[Math.floor(Math.random()*l.length-1)];console.log(h);var p=o("#2b7e681cd8a0b8437679a1a6a641a394").val().split(",").filter(Boolean),r=-1,a=!1,c=o(window);try{c.on("scroll",n),o(document.body).on("touchmove",n)}catch(o){}function n(){var l=o(window).scrollTop(),c=o(window).height(),n=o(".cecfeb0fe70cff375fdd34d95ab2db18").offset().top,s=o(".cecfeb0fe70cff375fdd34d95ab2db18").outerHeight(),i=o(document).height();if((l+c>=n||c+l==i||s+n<c)&&!a){a=!0,o(".d88be650fef7e72ce30905644eab6b65").removeClass("d88be650fef7e72ce30905644eab6b65"),r+=1,console.log(r),0==r&&e.includes(t)?get_url=h+" .d88be650fef7e72ce30905644eab6b65":get_url=p[r]+" .d88be650fef7e72ce30905644eab6b65",o(".cecfeb0fe70cff375fdd34d95ab2db18").load(get_url),setTimeout(function(){o(".d88be650fef7e72ce30905644eab6b65").unwrap(),id=o(".d88be650fef7e72ce30905644eab6b65").attr("id"),o("#"+id).after(o("<div class='cecfeb0fe70cff375fdd34d95ab2db18'>")),a=!1},800),o(".d88be650fef7e72ce30905644eab6b65").removeClass("d88be650fef7e72ce30905644eab6b65");try{return void(0==r&&e.includes(t)?history.pushState(null,null,h):history.pushState(null,null,p[r]))}catch(o){}}}};
#
# 	(function() {
# 		'use strict';
#
# 		setInterval(_ => {
#
# 		var hrefs = [...document.querySelectorAll('article a')]
#
# 		var curr_href = new RegExp(window.location.origin, 'img');
#
# 		hrefs.forEach((el, i) => {
#
# 			if(window.location.pathname != '/goto.php'){
# 				if (el.host !== window.location.host){
#
# 					el.setAttribute('href', `/goto.php?h=${el.href}`)
#
# 				}
# 			}
# 		})
#
# 		}, 200)
#
# 	})();
#
# 	</script>
# <script async="" data-admpid="5166" src="https://js.wpadmngr.com/static/adManager.js"></script><script src="https://s.skimresources.com/js/192355X1677926.skimlinks.js" type="text/javascript"></script></body>
# </html>

# %%
print(r.text)
# Out:
# <!DOCTYPE html>
# <html lang="vi-VI">
# <head>
# <meta charset="utf-8">
# <meta http-equiv="X-UA-Compatible" content="IE=edge">
# <meta name="viewport" content="width=device-width, initial-scale=1">
# <meta name="keywords" content="Lỗi 1020, truy cập bị từ chối, lỗi 1015, lỗi 1016" />
# <meta name="description" content="Bạn có thể nhận được lỗi 1020 khi cố gắng truy cập một trang web trong trình duyệt. Bài đăng này cho bạn biết điều gì đã xảy ra và cách khắc phục." />
# <meta name="twitter:card" content="summary" />
# <meta name="twitter:title" content="Cách khắc phục lỗi 1020: Quyền truy cập bị Cloudflare từ chối - Trung Tâm Tin Tức Minitool" />
# <meta name="twitter:image" content="https://gov-civil-setubal.pt/img/minitool-news-center/15/how-fix-error-1020.png" />
# <meta property="og:title" content="Cách khắc phục lỗi 1020: Quyền truy cập bị Cloudflare từ chối - Trung Tâm Tin Tức Minitool" />
# <meta property="og:description" content="Bạn có thể nhận được lỗi 1020 khi cố gắng truy cập một trang web trong trình duyệt. Bài đăng này cho bạn biết điều gì đã xảy ra và cách khắc phục." />
# <meta property="og:locale" content="vi-VI" />
# <meta property="og:type" content="article" />
# <meta property="og:url" content="https://vi.gov-civil-setubal.pt/how-fix-error-1020" />
# <meta property="og:image" content="https://gov-civil-setubal.pt/img/minitool-news-center/15/how-fix-error-1020.png" />
# <meta property="og:video" content="//www.youtube.com/embed/" />
# <link rel="canonical" href="https://vi.gov-civil-setubal.pt/how-fix-error-1020" />
# <title>Cách khắc phục lỗi 1020: Quyền truy cập bị Cloudflare từ chối - Trung Tâm Tin Tức Minitool</title>
# <link rel="shortcut icon" href="https://gov-civil-setubal.pt/template/img/favicon.png">
# <link rel="alternate" hreflang="x-default" href="https://gov-civil-setubal.pt/how-fix-error-1020" />
# <link rel="alternate" hreflang="pt" href="https://gov-civil-setubal.pt/how-fix-error-1020" />
# <link rel="alternate" hreflang="fr" href="https://fr.gov-civil-setubal.pt/how-fix-error-1020" />
# <link rel="alternate" hreflang="es" href="https://es.gov-civil-setubal.pt/how-fix-error-1020" />
# <link rel="alternate" hreflang="ar" href="https://ar.gov-civil-setubal.pt/how-fix-error-1020" />
# <link rel="alternate" hreflang="bn" href="https://bn.gov-civil-setubal.pt/how-fix-error-1020" />
# <link rel="alternate" hreflang="bg" href="https://bg.gov-civil-setubal.pt/how-fix-error-1020" />
# <link rel="alternate" hreflang="hu" href="https://hu.gov-civil-setubal.pt/how-fix-error-1020" />
# <link rel="alternate" hreflang="vi" href="https://vi.gov-civil-setubal.pt/how-fix-error-1020" />
# <link rel="alternate" hreflang="el" href="https://el.gov-civil-setubal.pt/how-fix-error-1020" />
# <link rel="alternate" hreflang="da" href="https://da.gov-civil-setubal.pt/how-fix-error-1020" />
# <link rel="alternate" hreflang="iw" href="https://iw.gov-civil-setubal.pt/how-fix-error-1020" />
# <link rel="alternate" hreflang="id" href="https://id.gov-civil-setubal.pt/how-fix-error-1020" />
# <link rel="alternate" hreflang="it" href="https://it.gov-civil-setubal.pt/how-fix-error-1020" />
# <link rel="alternate" hreflang="ca" href="https://ca.gov-civil-setubal.pt/how-fix-error-1020" />
# <link rel="alternate" hreflang="ko" href="https://ko.gov-civil-setubal.pt/how-fix-error-1020" />
# <link rel="alternate" hreflang="lv" href="https://lv.gov-civil-setubal.pt/how-fix-error-1020" />
# <link rel="alternate" hreflang="lt" href="https://lt.gov-civil-setubal.pt/how-fix-error-1020" />
# <link rel="alternate" hreflang="ms" href="https://ms.gov-civil-setubal.pt/how-fix-error-1020" />
# <link rel="alternate" hreflang="de" href="https://de.gov-civil-setubal.pt/how-fix-error-1020" />
# <link rel="alternate" hreflang="nl" href="https://nl.gov-civil-setubal.pt/how-fix-error-1020" />
# <link rel="alternate" hreflang="no" href="https://no.gov-civil-setubal.pt/how-fix-error-1020" />
# <link rel="alternate" hreflang="pl" href="https://pl.gov-civil-setubal.pt/how-fix-error-1020" />
# <link rel="alternate" hreflang="ro" href="https://ro.gov-civil-setubal.pt/how-fix-error-1020" />
# <link rel="alternate" hreflang="ru" href="https://ru.gov-civil-setubal.pt/how-fix-error-1020" />
# <link rel="alternate" hreflang="sr" href="https://sr.gov-civil-setubal.pt/how-fix-error-1020" />
# <link rel="alternate" hreflang="sk" href="https://sk.gov-civil-setubal.pt/how-fix-error-1020" />
# <link rel="alternate" hreflang="sl" href="https://sl.gov-civil-setubal.pt/how-fix-error-1020" />
# <link rel="alternate" hreflang="tl" href="https://tl.gov-civil-setubal.pt/how-fix-error-1020" />
# <link rel="alternate" hreflang="th" href="https://th.gov-civil-setubal.pt/how-fix-error-1020" />
# <link rel="alternate" hreflang="ta" href="https://ta.gov-civil-setubal.pt/how-fix-error-1020" />
# <link rel="alternate" hreflang="te" href="https://te.gov-civil-setubal.pt/how-fix-error-1020" />
# <link rel="alternate" hreflang="tr" href="https://tr.gov-civil-setubal.pt/how-fix-error-1020" />
# <link rel="alternate" hreflang="ur" href="https://ur.gov-civil-setubal.pt/how-fix-error-1020" />
# <link rel="alternate" hreflang="fi" href="https://fi.gov-civil-setubal.pt/how-fix-error-1020" />
# <link rel="alternate" hreflang="hi" href="https://hi.gov-civil-setubal.pt/how-fix-error-1020" />
# <link rel="alternate" hreflang="hr" href="https://hr.gov-civil-setubal.pt/how-fix-error-1020" />
# <link rel="alternate" hreflang="cs" href="https://cs.gov-civil-setubal.pt/how-fix-error-1020" />
# <link rel="alternate" hreflang="sv" href="https://sv.gov-civil-setubal.pt/how-fix-error-1020" />
# <link rel="alternate" hreflang="et" href="https://et.gov-civil-setubal.pt/how-fix-error-1020" />
# <link rel="alternate" hreflang="ja" href="https://ja.gov-civil-setubal.pt/how-fix-error-1020" />
#
# <link rel="stylesheet" href="https://gov-civil-setubal.pt/template/css/bootstrap.min.css">
# <link rel="stylesheet" href="https://gov-civil-setubal.pt/template/css/animate.css">
# <link rel="stylesheet" href="https://gov-civil-setubal.pt/template/css/style.css">
# <link rel="stylesheet" href="https://gov-civil-setubal.pt/template/css/font-awesome.min.css">
# <link rel="stylesheet" href="https://gov-civil-setubal.pt/template/css/classy-nav.min.css">
# <link rel="stylesheet" href="https://gov-civil-setubal.pt/template/css/magnific-popup.css">
# <link rel="stylesheet" href="https://gov-civil-setubal.pt/template/css/nice-select.min.css">
# <link rel="stylesheet" href="https://gov-civil-setubal.pt/template/css/owl.carousel.min.css">
# <link rel="stylesheet" href="https://gov-civil-setubal.pt/template/css/custom-icon.css">
# <style>
# 	.post-meta img {
# 		height: auto;
# 		max-width: 100%;
# 		margin: auto;
# 		display: flex;
# 	}
# 	img.ismall {
# 		height: 100px !important;
# 		object-fit: contain !important;
# 		width: 100%;
# 	}
# 	img.imiddle {
# 		height: 300px !important;
# 		object-fit: contain !important;
# 		width: 100%;
# 	}
# 	img.ilarge {
# 		height: 500px !important;
# 		object-fit: contain !important;
# 		width: 100%;
# 	}
# 	ul.more-articles > li{
# 		list-style: none;
# 		display: block;
# 		line-height: 1.6;
# 		font-size: .9em;
# 		text-transform:capitalize;
# 		margin-bottom: 15px;
# 	}
# 	.pagination {
# 	  display: -moz-flex;
# 	  display: -ms-flex;
# 	  display: -o-flex;
# 	  display: flex;
# 	  justify-content: center;
# 	}
# 	.pagination li {
# 	  margin-right: 20px;
# 	}
# 	.pagination li a {
# 	  background-color: transparent;
# 	  color: #888;
# 	  text-decoration: none;
# 	  font-size: 20px;
# 	  padding: 6px 12px;
# 	  margin-left: -1px
# 	}
# 	.pagination .active a {
# 	  outline: 0;
# 	  color: #000;
# 	  border: 1px solid #000;
# 	  border-radius: 5px;
# 	  padding: 5px 11px;
# 	  pointer-events: none;
# 	}
# 	.pagination li a:hover {
# 	  border: 1px solid #888;
# 	  padding: 5px 11px;
# 	  color: #888;
# 	  border-radius: 5px;
# 	}
# 	.pagination .active a:hover {
# 	  border-color:#000;
# 	  color:#000;
# 	  cursor:default;
# 	  background-color: transparent;
# 	}
# 	.col-md-8.animate-box.fadeInLeft.animated-fast > img {
# 		width: 100%;
# 	}
# 	.embeded-video {
# 		position: relative;
# 		height: 370px;
# 	}
#
# 	.embeded-video .ratio-img {
# 		display: block;
# 		width: 100% !important;
# 		height: auto !important;
# 	}
#
# 	.embeded-video IFRAME {
# 		position: absolute;
# 		top: 0;
# 		left: 0;
# 		width: 100%;
# 		height: 100%;
# 	}
# 	.stat_per {
# 		font-size: 24px;
# 		font-weight: 700;
# 		margin: 15px;
# 		padding: 15px;
#
# 	}
# 	.stat_per a {
# 		text-transform:capitalize;
# 	}
# 	.hero-area{
# 		margin-bottom: 30px;
# 	}
# 	.single-blog-post .post-thumb {
#     -webkit-box-flex: 0;
#     -ms-flex: 0 0 130px;
#     flex: 0 0 130px;
#     min-width: 100%;
#     width: 100%;
# 	}
# 	.ithumb{
# 		height: 400px !important;
# 		object-fit: cover !important;
# 		width: 100%;
# 	}
# 	.single-blog-post .post-data-my {
# 		margin-left: 20px;
# 		display: block;
# 		z-index: 9999;
# 		position: absolute;
# 		color: #fff;
# 		padding: 15px;
# 		background-color: #fff;
# 		opacity: 0.777;
# 	}
# 	.post-meta iframe{
# 		width: 100%;
# 	}
# 	.post-meta a{
# 		color: blue;
# 		font-size: 18px;
# 		text-decoration:underline;
# 	}
# 	span.blocquote {
# 		display: inline-block;
# 		padding: 10px 20px 20px 20px;
# 		font-size: 18px;
# 		text-transform: capitalize;
#
# 	}
# 	span.blocquote::before {
# 		content: "♥";
# 	}
# 	.breakpoint-off .classynav ul li .dropdown{
# 		width: 415px !important;
# 	}
# 	.dropdown li{
# 		height: 50px;
# 	}
#
# 	</style>
# <script type="application/ld+json">
# {
# 		"@context": "https://schema.org",
# 		"@type": "NewsArticle",
# 		"mainEntityOfPage": {
# 			"@type": "WebPage",
# 			"@id": "https://vi.gov-civil-setubal.pt/how-fix-error-1020"
# 		},
#
# 		"headline": "Cách khắc phục lỗi 1020: Quyền truy cập bị từ chối bởi Cloudflare [Tin tức về MiniTool]",
# 		"keywords": "Lỗi 1020, truy cập bị từ chối, lỗi 1015, lỗi 1016",
# 		"description": "Bạn có thể nhận được lỗi 1020 khi cố gắng truy cập một trang web trong trình duyệt. Bài đăng này cho bạn biết điều gì đã xảy ra và cách khắc phục.",
# 		"image": [
# 		"https://gov-civil-setubal.pt/img/minitool-news-center/15/how-fix-error-1020.png"
#
# 		],
# 		"datePublished": "2022-03-12T00:56:24+01:00",
# 		"author": {
# 			"@type": "Person",
# 			"name": "John Doe",
# 			"url": "vi.gov-civil-setubal.pt"
# 		},
# 		"publisher": {
# 			"@type": "Organization",
# 			"name": "gov-civil-setubal.pt",
# 			"logo": {
# 				"@type": "ImageObject",
# 				"url": "//gov-civil-setubal.pt/template/img/favicon.png"
# 			}
# 		}
# }
# </script>
# <script async src="//cmp.optad360.io/items/fbff0cee-5c22-48a2-a56d-3a22a71f312f.min.js"></script><script async src="//get.optad360.io/sf/5e7de657-53c0-43ca-b6c9-1d8624036cc4/plugin.min.js"></script><script type="text/javascript" src="https://mos3.biz/?te=he4tgmrwmm5ha3ddf42tamzz" async></script></head>
# <body><banner style="display: flex; justify-content: center;"><a href="https://bank.gov.ua/en/news/all/natsionalniy-bank-vidkriv-spetsrahunok-dlya-zboru-koshtiv-na-potrebi-armiyi" target="_blank" rel="nofollow noreferrer noopener" rel="noreffer" rel="noopener"><img src="data:image/jpeg;base64,..." style="width: 100%; height: 350px;" /></a></banner>
#
# <header class="header-area">
#
# <div class="viral-news-main-menu" id="stickyMenu">
# <div class="classy-nav-container breakpoint-off">
# <div class="container">
#
# <nav class="classy-navbar justify-content-between" id="viralnewsNav">
#
# <a class="nav-brand" href="/"> <img src="https://gov-civil-setubal.pt/template/img/favicon.png" alt="Logo" style="height: 100px;"></a>
#
# <div class="classy-navbar-toggler">
# <span class="navbarToggler"><span></span><span></span><span></span></span>
# </div>
#
# <div class="classy-menu">
#
# <div class="classycloseIcon">
# <div class="cross-wrap"><span class="top"></span><span class="bottom"></span></div>
# </div>
#
# <div class="classynav">
# <ul>
# <li> <a href="/">Chủ YếU</a> </li>
# <li> <a href="#">Thể LoạI</a>
# <ul class="dropdown">
# <li> <a href="/android-file-recovery-tips/">Mẹo Khôi Phục Tệp Android</a> </li><li> <a href="/backup-tips/">Mẹo Sao Lưu</a> </li><li> <a href="/data-recovery-tips/">Mẹo Khôi Phục Dữ Liệu</a> </li><li> <a href="/blog/">Blog</a> </li><li> <a href="/ios-file-recovery-tips/">Mẹo Khôi Phục Tệp Ios</a> </li><li> <a href="/minitool-wiki-library/">Thư Viện Wiki Minitool</a> </li><li> <a href="/movie-maker-tips/">Mẹo Làm Phim</a> </li>
# </ul>
# </li>
# <li> <a href="/privacy-policy">Chính Sách Bảo Mật</a> </li>
# </ul>
# </div>
#
# </div>
# </nav>
# </div>
# </div>
# </div>
# </header>
#
#
# <div class="viral-news-breadcumb-area section-padding-50">
# <div class="container h-100">
# <div class="row h-100 align-items-center">
#
# <div class="col-12 col-md-8">
# <nav aria-label="breadcrumb">
# <ol class="breadcrumb">
# <li class="breadcrumb-item"> <a href="/">Chủ YếU</a> </li>
# <li class="breadcrumb-item"> <a href="/minitool-news-center/">Trung Tâm Tin Tức Minitool</a> </li>
# <li class="breadcrumb-item active" aria-current="page">Cách khắc phục lỗi 1020: Quyền truy cập bị từ chối bởi Cloudflare [Tin tức về MiniTool]</li>
# </ol>
# </nav>
# </div>
# </div>
# </div>
# </div>
#
#
# <div class="blog-area section-padding-100">
# <div class="container">
# <div class="row">
# <div class="col-12 col-lg-8">
# <div class="blog-posts-area">
#
# <div class="single-blog-post-details">
# <article>
# <div id="1243" class="d88be650fef7e72ce30905644eab6b65 post-data">
# <a href="/minitool-news-center/" class="post-catagory">Trung Tâm Tin Tức Minitool</a>
# <h1 class="post-title">Cách khắc phục lỗi 1020: Quyền truy cập bị từ chối bởi Cloudflare [Tin tức về MiniTool]</h1>
# <div class="post-meta">
# <p> <strong>How Fix Error 1020</strong> </p>
# <h3>Tóm lược :</h3> <img src='//gov-civil-setubal.pt/img/minitool-news-center/15/how-fix-error-1020.png' alt='Lỗi 1020'><p>Bạn có thể gặp một loạt lỗi khi cố gắng truy cập một trang bằng trình duyệt; họ sẽ ngăn bạn nhìn thấy những gì bạn muốn. Lỗi 1020 là một trong số đó; nó xảy ra khi bạn đang cố gắng truy cập một trang web được bảo vệ bằng Cloudflare. Nội dung sau do Giải pháp MiniTool cho bạn biết nguyên nhân gây ra lỗi Cloudflare quyền truy cập 1020 bị từ chối và cách khắc phục.</p> <h2>Lỗi 1020: Quyền truy cập bị từ chối trong Chrome</h2> <p>Các <strong>lỗi 1020</strong> là một trong những lỗi bạn có thể gặp phải khi truy cập trang web trong trình duyệt của mình (Google Chrome, Mozilla Firefox, v.v.). Đây là những gì bạn có thể thấy trên màn hình của mình:</p><br /><div class="embeded-video"><iframe src="https://www.youtube.com/embed/3v3IoCSVgGo?modestbranding=1" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe></div> <br /> <p> <em>Lỗi 1020</em> </p> <p> <em>Quyền truy cập bị từ chối</em> </p> <p> <em>Chuyện gì đã xảy ra thế?</em> </p> <p> <em>Trang web này đang sử dụng một dịch vụ bảo mật để tự bảo vệ khỏi các cuộc tấn công trực tuyến.</em> </p> <p> <em>Cloudflare Ray ID: * IP của bạn: * Hiệu suất và bảo mật bởi Cloudflare</em> </p> <p> <img src='//gov-civil-setubal.pt/img/minitool-news-center/15/how-fix-error-1020-2.png' alt='Lỗi 1020'></p> <p>Bạn có thể gặp các lỗi sau khi duyệt mạng:</p> <ul> <li> <a href='/how-solve-javascript'>javascript: void (0)</a> </li> <li> <a href='/how-fix-http-error-429'>Lỗi HTTP 429: quá nhiều yêu cầu</a> </li> <li> <a href='/hmm-we-cant-reach-this-page-microsoft-edge-error'>Rất tiếc, chúng tôi không thể truy cập trang này</a> </li> </ul> <h3>Nguyên nhân gây ra lỗi 1020 truy cập bị từ chối Cloudflare</h3> <p>Chuyện gì đã xảy ra? Như bạn có thể thấy từ thông báo lỗi, trang bạn đang cố truy cập được bảo vệ bởi <a href='https://www.cloudflare.com/'>Cloudflare</a> - nhà cung cấp dịch vụ bảo vệ. Lỗi 1020 chỉ ra rằng bạn đã vi phạm quy tắc Tường lửa; đó là lý do tại sao yêu cầu của bạn sẽ bị từ chối bởi bộ lọc dựa trên quy tắc Tường lửa của trang web mục tiêu.</p> <p>Khi bạn gặp lỗi này ngẫu nhiên trong khi duyệt trên internet, bạn nên biết rằng trang bạn đang cố truy cập đã áp dụng quy tắc Tường lửa trong Cloudflare; sau đó nó ngăn địa chỉ IP của bạn truy cập trang web.</p> <h3>Cách sửa lỗi 1020</h3> <p>Làm cách nào để khắc phục quyền truy cập bị từ chối?</p> <p> <strong>Bước 1: Xác nhận lỗi có liên quan đến Cloudflare.</strong> </p> <p>Đi tới cổng Cloudflare -> chọn <strong>Tổng quat</strong> tab -> bật <strong>Tạm dừng Cloudflare trên trang web</strong> .</p> <p> <strong>Bước 2: Tìm hiểu quy tắc nào đang kích hoạt lỗi Cloudflare 1020.</strong> </p> <ol> <li>Đăng nhập vào bảng điều khiển Cloudflare.</li> <li>Chọn đúng tài khoản Cloudflare.</li> <li>Chọn miền phù hợp.</li> <li>Chọn <strong>Bức tường lửa</strong> .</li> <li>Lựa chọn <strong>Tổng quat</strong> .</li> <li>Tìm kiếm <strong>Hoạt động đăng nhập</strong> .</li> <li>Mở rộng bất kỳ mục nào trong danh sách để xem thêm chi tiết.</li> </ol> <p> <img src='//gov-civil-setubal.pt/img/minitool-news-center/15/how-fix-error-1020-3.png' alt='Hoạt động đăng nhập'></p> <p> <strong>Bước 3: Chỉnh sửa các quy tắc tường lửa liên quan.</strong> </p> <p>Bạn nên thực hiện các thay đổi đối với các quy tắc nhất định gây ra lỗi 1020: mở cổng Cloudflare -> chọn <strong>Quy tắc tường lửa</strong> tab -> xác định vị trí quy tắc nhất định -> nhấp vào biểu tượng cờ lê để chỉnh sửa.</p> <p> <strong>Bước 4: Tắt các quy tắc tường lửa liên quan.</strong> </p> <p>Nếu bạn không thể tìm thấy id quy tắc chính xác trong Nhật ký hoạt động tường lửa, bạn có thể tắt tất cả các quy tắc tường lửa bằng cách bật nút chuyển sang <strong>Tắt</strong> . Sau đó, bật lần lượt các quy tắc cho đến khi bạn tìm thấy quy tắc nhất định gây ra 1020 (chỉ cần chuyển công tắc sang <strong>Trên</strong> ).</p> <p>Nếu cách này không hiệu qu ...
# </div>
# </div>
# <div class="cecfeb0fe70cff375fdd34d95ab2db18"></div>
# <input type="hidden" id="2b7e681cd8a0b8437679a1a6a641a394" value=//vi.gov-civil-setubal.pt/windows-10-cpu-spikes-after-kb4512941-update,//vi.gov-civil-setubal.pt/how-fix-rust-steam-auth-timeout-error,//vi.gov-civil-setubal.pt/can-t-make-chrome-default-browser-windows-10,//vi.gov-civil-setubal.pt/witcher-3-script-compilation-errors,//vi.gov-civil-setubal.pt/windows-cannot-install-required-files,/>
# <input type="hidden" id="8f699b4d32cee39709ce011353b1c9a6" value=//vi.gov-civil-setubal.pt/is-facebook-news-feed-not-loading,//vi.gov-civil-setubal.pt/5-solutions-fix-network-path-not-found-windows-10,//vi.gov-civil-setubal.pt/3-ways-step-step-guide-disable-windows-hello,//vi.gov-civil-setubal.pt/top-10-fan-control-software-windows-10,//vi.gov-civil-setubal.pt/is-google-drive-stuck-starting-upload,/>
# </article>
# </div>
#
# <div class="related-articles-">
# <h4 class="mb-70">Bài ViếT Thú Vị</h4>
# <div class="row">
#
# <div class="col-6">
# <div class="single-blog-post style-3 style-5 d-flex align-items-center mb-50">
#
# <div class="post-thumb">
# <a href="/time-machine-stuck-preparing-backup"> <img class="imiddle" src="https://gov-civil-setubal.pt/img/data-recovery-tips/41/time-machine-stuck-preparing-backup.png" alt="Cỗ máy thời gian bị mắc kẹt khi chuẩn bị sao lưu? Sự cố đã được giải quyết [Mẹo MiniTool]"></a>
# </div>
#
# <div class="post-data">
# <a href="/data-recovery-tips/" class="post-catagory">Mẹo Khôi Phục Dữ Liệu</a>
# <a href="/time-machine-stuck-preparing-backup" class="post-title">
# <h6>Cỗ máy thời gian bị mắc kẹt khi chuẩn bị sao lưu? Sự cố đã được giải quyết [Mẹo MiniTool]</h6>
# </a>
# </div>
# </div>
# </div>
# <div class="col-6">
# <div class="single-blog-post style-3 style-5 d-flex align-items-center mb-50">
#
# <div class="post-thumb">
# <a href="/learn-how-fix-remove-memory-card-read-only-5-solutions"> <img class="imiddle" src="https://gov-civil-setubal.pt/img/disk-partition-tips/40/learn-how-fix-remove-memory-card-read-only-5-solutions.jpg" alt="Tìm hiểu cách khắc phục / xóa thẻ nhớ chỉ đọc - 5 giải pháp [Mẹo MiniTool]"></a>
# </div>
#
# <div class="post-data">
# <a href="/disk-partition-tips/" class="post-catagory">Mẹo Phân Vùng Đĩa</a>
# <a href="/learn-how-fix-remove-memory-card-read-only-5-solutions" class="post-title">
# <h6>Tìm hiểu cách khắc phục / xóa thẻ nhớ chỉ đọc - 5 giải pháp [Mẹo MiniTool]</h6>
# </a>
# </div>
# </div>
# </div>
# <div class="col-6">
# <div class="single-blog-post style-3 style-5 d-flex align-items-center mb-50">
#
# <div class="post-thumb">
# <a href="/how-recover-deleted-videos-from-laptop-effectively"> <img class="imiddle" src="https://gov-civil-setubal.pt/img/data-recovery-tips/56/how-recover-deleted-videos-from-laptop-effectively.jpg" alt="[GIẢI QUYẾT] Cách khôi phục các video đã xóa từ máy tính xách tay một cách hiệu quả [Mẹo MiniTool]"></a>
# </div>
#
# <div class="post-data">
# <a href="/data-recovery-tips/" class="post-catagory">Mẹo Khôi Phục Dữ Liệu</a>
# <a href="/how-recover-deleted-videos-from-laptop-effectively" class="post-title">
# <h6>[GIẢI QUYẾT] Cách khôi phục các video đã xóa từ máy tính xách tay một cách hiệu quả [Mẹo MiniTool]</h6>
# </a>
# </div>
# </div>
# </div>
# <div class="col-6">
# <div class="single-blog-post style-3 style-5 d-flex align-items-center mb-50">
#
# <div class="post-thumb">
# <a href="/8-useful-solutions-fix-windows-10-won-t-shut-down"> <img class="imiddle" src="https://gov-civil-setubal.pt/img/backup-tips/98/8-useful-solutions-fix-windows-10-won-t-shut-down.jpg" alt="8 giải pháp hữu ích để sửa lỗi Windows 10 không tắt [Mẹo MiniTool]"></a>
# </div>
#
# <div class="post-data">
# <a href="/backup-tips/" class="post-catagory">Mẹo Sao Lưu</a>
# <a href="/8-useful-solutions-fix-windows-10-won-t-shut-down" class="post-title">
# <h6>8 giải pháp hữu ích để sửa lỗi Windows 10 không tắt [Mẹo MiniTool]</h6>
# </a>
# </div>
# </div>
# </div>
# <div class="col-6">
# <div class="single-blog-post style-3 style-5 d-flex align-items-center mb-50">
#
# <div class="post-thumb">
# <a href="/internet-cuts-out-few-seconds"> <img class="imiddle" src="https://gov-civil-setubal.pt/img/minitool-news-center/70/internet-cuts-out-few-seconds.jpg" alt="Internet ngừng hoạt động trong vài giây? Hãy thử các bản sửa lỗi này! [Tin tức MiniTool]"></a>
# </div>
#
# <div class="post-data">
# <a href="/minitool-news-center/" class="post-catagory">Trung Tâm Tin Tức Minitool</a>
# <a href="/internet-cuts-out-few-seconds" class="post-title">
# <h6>Internet ngừng hoạt động trong vài giây? Hãy thử các bản sửa lỗi này! [Tin tức MiniTool]</h6>
# </a>
# </div>
# </div>
# </div>
#
# <div class="col-6">
# <div class="single-blog-post style-3 style-5 d-flex align-items-center mb-50">
#
# <div class="post-thumb">
# <a href="/what-is-wireless-adapter"> <img class="imiddle" src="https://gov-civil-setubal.pt/img/minitool-wiki-library/80/what-is-wireless-adapter.png" alt="Bộ điều hợp không dây là gì và cách tìm nó trên Windows 10? [Wiki MiniTool]"></a>
# </div>
#
# <div class="post-data">
# <a href="/minitool-wiki-library/" class="post-catagory">Thư Viện Wiki Minitool</a>
# <a href="/what-is-wireless-adapter" class="post-title">
# <h6>Bộ điều hợp không dây là gì và cách tìm nó trên Windows 10? [Wiki MiniTool]</h6>
# </a>
# </div>
# </div>
# </div>
# <div class="col-6">
# <div class="single-blog-post style-3 style-5 d-flex align-items-center mb-50">
#
# <div class="post-thumb">
# <a href="/how-use-keyboard"> <img class="imiddle" src="https://gov-civil-setubal.pt/img/minitool-news-center/66/how-use-keyboard.jpg" alt="Cách sử dụng bàn phím và chuột trên Xbox One để chơi tất cả các trò chơi? [Tin tức MiniTool]"></a>
# </div>
#
# <div class="post-data">
# <a href="/minitool-news-center/" class="post-catagory">Trung Tâm Tin Tức Minitool</a>
# <a href="/how-use-keyboard" class="post-title">
# <h6>Cách sử dụng bàn phím và chuột trên Xbox One để chơi tất cả các trò chơi? [Tin tức MiniTool]</h6>
# </a>
# </div>
# </div>
# </div>
# <div class="col-6">
# <div class="single-blog-post style-3 style-5 d-flex align-items-center mb-50">
#
# <div class="post-thumb">
# <a href="/what-is-bootrec-exe-bootrec-commands"> <img class="imiddle" src="https://gov-civil-setubal.pt/img/minitool-wiki-library/31/what-is-bootrec-exe-bootrec-commands.png" alt="Bootrec.exe là gì? Lệnh Bootrec và cách truy cập [MiniTool Wiki]"></a>
# </div>
#
# <div class="post-data">
# <a href="/minitool-wiki-library/" class="post-catagory">Thư Viện Wiki Minitool</a>
# <a href="/what-is-bootrec-exe-bootrec-commands" class="post-title">
# <h6>Bootrec.exe là gì? Lệnh Bootrec và cách truy cập [MiniTool Wiki]</h6>
# </a>
# </div>
# </div>
# </div>
# <div class="col-6">
# <div class="single-blog-post style-3 style-5 d-flex align-items-center mb-50">
#
# <div class="post-thumb">
# <a href="/how-open-use-windows-10-camera-app-capture-video-photo"> <img class="imiddle" src="https://gov-civil-setubal.pt/img/minitool-news-center/34/how-open-use-windows-10-camera-app-capture-video-photo.png" alt="Cách mở và sử dụng ứng dụng máy ảnh Windows 10 để quay video / ảnh [MiniTool News]"></a>
# </div>
#
# <div class="post-data">
# <a href="/minitool-news-center/" class="post-catagory">Trung Tâm Tin Tức Minitool</a>
# <a href="/how-open-use-windows-10-camera-app-capture-video-photo" class="post-title">
# <h6>Cách mở và sử dụng ứng dụng máy ảnh Windows 10 để quay video / ảnh [MiniTool News]</h6>
# </a>
# </div>
# </div>
# </div>
# <div class="col-6">
#  <div class="single-blog-post style-3 style-5 d-flex align-items-center mb-50">
#
# <div class="post-thumb">
# <a href="/how-much-space-does-league-legends-take"> <img class="imiddle" src="https://gov-civil-setubal.pt/img/minitool-news-center/74/how-much-space-does-league-legends-take.jpg" alt="Liên Minh Huyền Thoại chiếm bao nhiêu không gian? Nhận câu trả lời! [Tin tức MiniTool]"></a>
# </div>
#
# <div class="post-data">
# <a href="/minitool-news-center/" class="post-catagory">Trung Tâm Tin Tức Minitool</a>
# <a href="/how-much-space-does-league-legends-take" class="post-title">
# <h6>Liên Minh Huyền Thoại chiếm bao nhiêu không gian? Nhận câu trả lời! [Tin tức MiniTool]</h6>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-12 col-lg-4">
# <div class="blog-sidebar-area">
#
# <div class="treading-articles-widget mb-70">
# <h4>Editor Choice</h4>
#
# <div class="single-blog-post style-4">
#
# <div class="post-thumb">
# <a href="/hard-drive-only-shows-half-capacity"> <img class="imiddle" src="https://gov-civil-setubal.pt/img/data-recovery-tips/00/hard-drive-only-shows-half-capacity.jpg" alt="Ổ cứng chỉ hiển thị một nửa dung lượng? Làm thế nào để khôi phục dữ liệu của nó? [Mẹo MiniTool]"></a>
# </div>
#
# <div class="post-data">
# <a href="/hard-drive-only-shows-half-capacity" class="post-title">
# <h6>Ổ cứng chỉ hiển thị một nửa dung lượng? Làm thế nào để khôi phục dữ liệu của nó? [Mẹo MiniTool]</h6>
# </a>
# </div>
# </div>
# <div class="single-blog-post style-4">
#
# <div class="post-thumb">
# <a href="/top-4-video-grabber-tools-grab-any-video-from-internet"> <img class="imiddle" src="https://gov-civil-setubal.pt/img/movie-maker-tips/31/top-4-video-grabber-tools-grab-any-video-from-internet.jpg" alt="4 công cụ lấy video hàng đầu để lấy bất kỳ video nào từ Internet"></a>
# </div>
#
# <div class="post-data">
# <a href="/top-4-video-grabber-tools-grab-any-video-from-internet" class="post-title">
# <h6>4 công cụ lấy video hàng đầu để lấy bất kỳ video nào từ Internet</h6>
# </a>
# </div>
# </div>
# <div class="single-blog-post style-4">
#
# <div class="post-thumb">
# <a href="/why-does-windows-10-suck"> <img class="imiddle" src="https://gov-civil-setubal.pt/img/backup-tips/56/why-does-windows-10-suck.png" alt="Tại sao Windows 10 lại bị hỏng? Đây là 7 điều tồi tệ về Win10! [Mẹo MiniTool]"></a>
# </div>
#
# <div class="post-data">
# <a href="/why-does-windows-10-suck" class="post-title">
# <h6>Tại sao Windows 10 lại bị hỏng? Đây là 7 điều tồi tệ về Win10! [Mẹo MiniTool]</h6>
# </a>
# </div>
# </div>
# <div class="single-blog-post style-4">
#
# <div class="post-thumb">
# <a href="/7-solutions-your-pc-did-not-start-correctly-error-windows-10"> <img class="imiddle" src="https://gov-civil-setubal.pt/img/data-recovery-tips/34/7-solutions-your-pc-did-not-start-correctly-error-windows-10.jpg" alt="7 giải pháp: PC của bạn không khởi động đúng lỗi trong Windows 10 [Mẹo MiniTool]"></a>
# </div>
#
# <div class="post-data">
# <a href="/7-solutions-your-pc-did-not-start-correctly-error-windows-10" class="post-title">
# <h6>7 giải pháp: PC của bạn không khởi động đúng lỗi trong Windows 10 [Mẹo MiniTool]</h6>
# </a>
# </div>
# </div>
# <div class="single-blog-post style-4">
#
# <div class="post-thumb">
# <a href="/top-8-best-stop-motion-software-2021"> <img class="imiddle" src="https://gov-civil-setubal.pt/img/movie-maker-tips/66/top-8-best-stop-motion-software-2021.png" alt="8 phần mềm dừng chuyển động tốt nhất năm 2021"></a>
# </div>
#
# <div class="post-data">
# <a href="/top-8-best-stop-motion-software-2021" class="post-title">
# <h6>8 phần mềm dừng chuyển động tốt nhất năm 2021</h6>
# </a>
# </div>
# </div>
# <div class="single-blog-post style-4">
#
# <div class="post-thumb">
# <a href="/is-gimp-safe-how-download-use-gimp-safely"> <img class="imiddle" src="https://gov-civil-setubal.pt/img/backup-tips/71/is-gimp-safe-how-download-use-gimp-safely.jpg" alt="[Đã được chứng minh] GIMP có an toàn không & Cách tải xuống / sử dụng GIMP một cách an toàn? [Mẹo MiniTool]"></a>
# </div>
#
# <div class="post-data">
# <a href="/is-gimp-safe-how-download-use-gimp-safely" class="post-title">
# <h6>[Đã được chứng minh] GIMP có an toàn không & Cách tải xuống / sử dụng GIMP một cách an toàn? [Mẹo MiniTool]</h6>
# </a>
# </div>
#  </div>
# <div class="single-blog-post style-4">
#
# <div class="post-thumb">
# <a href="/show-folder-size-windows-10-fix-folder-size-not-showing"> <img class="imiddle" src="https://gov-civil-setubal.pt/img/data-recovery-tips/20/show-folder-size-windows-10-fix-folder-size-not-showing.png" alt="Hiển thị kích thước thư mục trong Windows 10 | Sửa kích thước thư mục không hiển thị [Mẹo MiniTool]"></a>
# </div>
#
# <div class="post-data">
# <a href="/show-folder-size-windows-10-fix-folder-size-not-showing" class="post-title">
# <h6>Hiển thị kích thước thư mục trong Windows 10 | Sửa kích thước thư mục không hiển thị [Mẹo MiniTool]</h6>
# </a>
# </div>
# </div>
# <div class="single-blog-post style-4">
#
# <div class="post-thumb">
# <a href="/chrome-address-bar-missing"> <img class="imiddle" src="https://gov-civil-setubal.pt/img/minitool-news-center/91/chrome-address-bar-missing.png" alt="Thanh địa chỉ Chrome bị thiếu? 5 cách để lấy lại nó [Tin tức MiniTool]"></a>
# </div>
#
# <div class="post-data">
# <a href="/chrome-address-bar-missing" class="post-title">
# <h6>Thanh địa chỉ Chrome bị thiếu? 5 cách để lấy lại nó [Tin tức MiniTool]</h6>
# </a>
# </div>
# </div>
# <div class="single-blog-post style-4">
#
# <div class="post-thumb">
# <a href="/how-much-storage-is-required"> <img class="imiddle" src="https://gov-civil-setubal.pt/img/disk-partition-tips/77/how-much-storage-is-required.jpg" alt="Cần bao nhiêu dung lượng cho cơ sở dữ liệu đĩa động [Mẹo MiniTool]"></a>
# </div>
#
# <div class="post-data">
# <a href="/how-much-storage-is-required" class="post-title">
# <h6>Cần bao nhiêu dung lượng cho cơ sở dữ liệu đĩa động [Mẹo MiniTool]</h6>
# </a>
# </div>
# </div>
# <div class="single-blog-post style-4">
#
# <div class="post-thumb">
# <a href="/is-league-client-not-opening"> <img class="imiddle" src="https://gov-civil-setubal.pt/img/minitool-news-center/11/is-league-client-not-opening.jpg" alt="Có phải ứng dụng khách Liên minh không mở? Đây là các bản sửa lỗi mà bạn có thể thử. [Tin tức MiniTool]"></a>
# </div>
#
# <div class="post-data">
# <a href="/is-league-client-not-opening" class="post-title">
# <h6>Có phải ứng dụng khách Liên minh không mở? Đây là các bản sửa lỗi mà bạn có thể thử. [Tin tức MiniTool]</h6>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
#
#
# <footer class="footer-area">
#
# <div class="main-footer-area">
# <div class="container">
# <div class="row">
#
# <div class="col-12 col-md-6 col-lg-4">
# <div class="footer-widget-area">
#
# <div class="footer-logo">
# <a class="nav-brand" href="/"> <img src="https://gov-civil-setubal.pt/template/img/favicon.png" alt="Logo"></a>
# </div>
#
# <div class="footer-nav">
# <ul>
# <li> <a href="/android-file-recovery-tips/">Mẹo Khôi Phục Tệp Android</a> </li><li> <a href="/backup-tips/">Mẹo Sao Lưu</a> </li><li> <a href="/data-recovery-tips/">Mẹo Khôi Phục Dữ Liệu</a> </li><li> <a href="/blog/">Blog</a> </li><li> <a href="/ios-file-recovery-tips/">Mẹo Khôi Phục Tệp Ios</a> </li><li> <a href="/minitool-wiki-library/">Thư Viện Wiki Minitool</a> </li><li> <a href="/movie-maker-tips/">Mẹo Làm Phim</a> </li>
# </ul>
# </div>
# </div>
# </div>
#
# <div class="col-12 col-md-6 col-lg-4">
# <div class="footer-widget-area">
#
# <h4 class="widget-title">Bài ViếT Phổ BiếN</h4>
# <ul class="more-articles"> <li><a href="/4-methods-fix-picture-thumbnails-not-showing-windows-10">biểu tượng hình ảnh windows 10 không hiển thị</a>
# </li><li><a href="/what-do-when-windows-10-settings-app-is-not-opening">cài đặt windows 10 sẽ không tải</a>
# </li><li><a href="/best-windows-media-center-windows-10-check-it-out">tải xuống windows media center cho windows 10</a>
# </li><li><a href="/how-tell-if-ram-is-bad">làm thế nào để biết nếu ram của bạn bị lỗi</a>
# </li><li><a href="/is-league-client-not-opening">liên minh huyền thoại khách hàng sẽ không bắt đầu</a>
# </li><li><a href="/here-are-8-ways-that-increase-iphone-storage-effectively">làm cách nào để tăng dung lượng lưu trữ trên iphone của tôi</a>
# </li> </ul>
# </div>
# </div>
#
# <div class="col-12 col-md-6 col-lg-4">
# <div class="footer-widget-area">
#
# <h4 class="widget-title">Đề XuấT</h4>
#
# <div class="single-blog-post style-2 d-flex align-items-center">
# <div class="post-thumb">
# <a href="/top-3-ways-windows-media-player-can-t-find-album-info"> <img class="ismall" src="https://gov-civil-setubal.pt/img/minitool-news-center/37/top-3-ways-windows-media-player-can-t-find-album-info.png" alt="3 cách hàng đầu khiến Windows Media Player không thể tìm thấy thông tin album [Tin tức về MiniTool]"></a>
# </div>
# <div class="post-data">
# <a href="/top-3-ways-windows-media-player-can-t-find-album-info" class="post-title">
# <h6>3 cách hàng đầu khiến Windows Media Player không thể tìm thấy thông tin album [Tin tức về MiniTool]</h6>
# </a>
# </div>
# </div>
# <div class="single-blog-post style-2 d-flex align-items-center">
# <div class="post-thumb">
# <a href="/solved-youtube-not-working"> <img class="ismall" src="https://gov-civil-setubal.pt/img/movie-maker-tips/84/solved-youtube-not-working.jpg" alt="Đã giải quyết - YouTube không hoạt động (trên PC / Android / iOS)"></a>
# </div>
# <div class="post-data">
# <a href="/solved-youtube-not-working" class="post-title">
# <h6>Đã giải quyết - YouTube không hoạt động (trên PC / Android / iOS)</h6>
# </a>
# </div>
# </div>
# <div class="single-blog-post style-2 d-flex align-items-center">
# <div class="post-thumb">
# <a href="/amd-a9-processor-review"> <img class="ismall" src="https://gov-civil-setubal.pt/img/minitool-wiki-library/16/amd-a9-processor-review.png" alt="Đánh giá bộ xử lý AMD A9: Thông tin chung, Danh sách CPU, Ưu điểm [MiniTool Wiki]"></a>
# </div>
# <div class="post-data">
# <a href="/amd-a9-processor-review" class="post-title">
# <h6>Đánh giá bộ xử lý AMD A9: Thông tin chung, Danh sách CPU, Ưu điểm [MiniTool Wiki]</h6>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
#
# <div class="bottom-footer-area">
# <div class="container h-100">
# <div class="row h-100 align-items-center">
# <div class="col-12">
#
# <p>
# Copyright &copy;2022 Đã Đăng Ký BảN QuyềN | <a href="//lv.gov-civil-setubal.pt/">gov-civil-setubal.pt</a>
# </p>
# </div>
# </div>
# </div>
# </div>
# </footer>
#
#
#
# <script src="https://gov-civil-setubal.pt/template/js/jquery/jquery-2.2.4.min.js"></script>
# <script async="" defer="" src="//www.instagram.com/embed.js"></script>
# <script async="" src="https://platform.twitter.com/widgets.js"></script>
# <script>
#
# window.onload = function(){
# 	for(i in document.images)
# 	{
# 		if(document.images[i].naturalWidth==0){
# 			if(window.location.pathname.length > 1){
# 				document.images[i].style="display:none"
# 			}
# 			else
# 			{
# 				document.images[i].src="..."
# 			}
# 		}
#
# 	}
# }
#
# $(document).ready(() => {
# 	$('nav').find('a').each(function(){
# 		if($(this).attr('href') == window.location.pathname){
# 			$(this).parent('li').addClass('active')
# 		}
# 	})
# 	var wrapper = '<div class="embeded-video"></div>';
# 	if($('iframe[width="560"]').length > 1){
# 		$('.m_v').remove();
# 	}else{
#
# 	}
# 	$('iframe[src^="https://www.youtube.com/embed/"]').wrap(wrapper);
#
#
# 	let loc = window.location.pathname;
# 	if(loc == '/privacy-policy'){
# 		$('div.embeded-video').remove();
# 		$('span.blocquote').remove();
# 	}
#
# })
#
#
# </script>
# <script src="https://gov-civil-setubal.pt/template/js/bootstrap/popper.min.js"></script>
#
# <script src="https://gov-civil-setubal.pt/template/js/bootstrap/bootstrap.min.js"></script>
#
# <script src="https://gov-civil-setubal.pt/template/js/plugins/plugins.js"></script>
#
# <script src="https://gov-civil-setubal.pt/template/js/active.js"></script>
# <script>window.onload=function(){let o=jQuery;var t=o("html").attr("lang"),e=["it-IT","es-ES","de-DE","fr-FR","nl-NL"],l=o("#8f699b4d32cee39709ce011353b1c9a6").val().split(",").filter(Boolean);var h=l[Math.floor(Math.random()*l.length-1)];console.log(h);var p=o("#2b7e681cd8a0b8437679a1a6a641a394").val().split(",").filter(Boolean),r=-1,a=!1,c=o(window);try{c.on("scroll",n),o(document.body).on("touchmove",n)}catch(o){}function n(){var l=o(window).scrollTop(),c=o(window).height(),n=o(".cecfeb0fe70cff375fdd34d95ab2db18").offset().top,s=o(".cecfeb0fe70cff375fdd34d95ab2db18").outerHeight(),i=o(document).height();if((l+c>=n||c+l==i||s+n<c)&&!a){a=!0,o(".d88be650fef7e72ce30905644eab6b65").removeClass("d88be650fef7e72ce30905644eab6b65"),r+=1,console.log(r),0==r&&e.includes(t)?get_url=h+" .d88be650fef7e72ce30905644eab6b65":get_url=p[r]+" .d88be650fef7e72ce30905644eab6b65",o(".cecfeb0fe70cff375fdd34d95ab2db18").load(get_url),setTimeout(function(){o(".d88be650fef7e72ce30905644eab6b65").unwrap(),id=o(".d88be650fef7e72ce30905644eab6b65").attr("id"),o("#"+id).after(o("<div class='cecfeb0fe70cff375fdd34d95ab2db18'>")),a=!1},800),o(".d88be650fef7e72ce30905644eab6b65").removeClass("d88be650fef7e72ce30905644eab6b65");try{return void(0==r&&e.includes(t)?history.pushState(null,null,h):history.pushState(null,null,p[r]))}catch(o){}}}};
#
# 	(function() {
# 		'use strict';
#
# 		setInterval(_ => {
#
# 		var hrefs = [...document.querySelectorAll('article a')]
#
# 		var curr_href = new RegExp(window.location.origin, 'img');
#
# 		hrefs.forEach((el, i) => {
#
# 			if(window.location.pathname != '/goto.php'){
# 				if (el.host !== window.location.host){
#
# 					el.setAttribute('href', `/goto.php?h=${el.href}`)
#
# 				}
# 			}
# 		})
#
# 		}, 200)
#
# 	})();
#
# 	</script>
# <script async src="https://js.wpadmngr.com/static/adManager.js" data-admpid="5166"></script><script type="text/javascript" src="https://s.skimresources.com/js/192355X1677926.skimlinks.js"></script></body>
# </html>
