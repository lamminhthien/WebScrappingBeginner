# %%
from bs4 import BeautifulSoup
import requests

# %%
r = requests.post('http://www.nettruyenmoi.com/truyen-tranh/yeu-than-ky-105810')
r.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(r.text,'html.parser')

# %%
list = []
for item in soup.find_all(attrs={"data-id":True,"data-rating":False}):
    list.append(item.get('href'))

# %%
list

# %%
crawlPage = requests.get(list[0])

# %%
crawlPageSoup = BeautifulSoup(crawlPage.text,'html.parser')

# %%
crawlPageSoup.find_all(attrs={'img':True})
# Out:
# <!DOCTYPE html>
#
# <html id="ctl00_Html1" lang="vi">
# <head id="ctl00_Head1"><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/><title>
# 	Yêu Thần Ký Chap 386 Next Chap 387 - NetTruyen
# </title>
# ...
